# %%
import numpy as np
import pandas as pd

# %%
covid = pd.read_csv('country_wise_latest.csv')
covid['Country/Region'].is_unique #True
covid.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
gone_case = pd.read_csv('addiction_population_data.csv')
gone_case.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         3000 non-null   int64
#  1   name                       3000 non-null   str
#  2   age                        3000 non-null   int64
#  3   gender                     3000 non-null   str
#  4   country                    3000 non-null   str
#  5   city                       3000 non-null   str
#  6   education_level            2580 non-null   str
#  7   employment_status          3000 non-null   str
#  8   annual_income_usd          3000 non-null   int64
#  9   marital_status             3000 non-null   str
#  10  children_count             3000 non-null   int64
#  11  smokes_per_day             3000 non-null   int64
#  12  drinks_per_week            3000 non-null   int64
#  13  age_started_smoking        3000 non-null   int64
# ...

# %% [markdown]
# ## Boolean Filtering <hr>
# `syntax : variable[ condtion ]`

# %%
covid[covid['Country/Region'] == 'India']

# covid[covid['Country/Region']] # error coz no condtion  and it is a syntax of indexing

covid[covid['Deaths'] > 33000]

covid[(covid['Deaths'] > 10000) & (covid['New deaths'] > 20)]

covid[(covid['New cases'] > 1000) & (covid['Deaths'] > 10000) ]['Country/Region']
# Out:
# 23     Brazil
# 61     France
# 79      India
# 81       Iran
# 111    Mexico
# 132      Peru
# 138    Russia
# 173        US
# Name: Country/Region, dtype: str

# %%
gone_case[gone_case['smokes_per_day'] > 18 ]

gone_case[(gone_case['smokes_per_day'] > 15) & (gone_case['gender'] == 'Male' ) ]

gone_case[(gone_case['smokes_per_day'] > 15) & (gone_case['gender'] == 'Male' ) ]['id'].count()

gone_case[(gone_case['smokes_per_day'] > 15) & (gone_case['gender'] == 'Female')]['id'].count()

# gone_case[(covid['Deaths'] > 15) & (gone_case['gender'] == 'Female')]['id'] # works but not prefered

# gone_case[ np.int32(10) ]  # this is indexing
# Out:
# np.int64(62)

# %% [markdown]
# ## Modification <hr>

# %% [markdown]
# #### modification of specific values

# %%
gone_case['name'][1] = 'Jay'
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6708\4262450427.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   gone_case['name'][1] = 'Jay'

# %%
gone_case.loc[::, 'name' ][1] = 'Jay'
gone_case
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6708\265650032.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   gone_case.loc[::, 'name' ][1] = 'Jay'
#         id              name  age  gender                      country  \
# 0        1     Michael Bates   66   Other                        Yemen
# 1        2    Brian Thompson   29    Male                 Saudi Arabia
# 2        3     Steven Little   75    Male                         Togo
# ...

# %%
gone_case['age'][0] = 30
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6708\3312670268.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   gone_case['age'][0] = 30

# %%
gone_case['age'] = 30
gone_case
# Out:
#         id              name  age  gender                      country  \
# 0        1     Michael Bates   30   Other                        Yemen
# 1        2    Brian Thompson   30    Male                 Saudi Arabia
# 2        3     Steven Little   30    Male                         Togo
# 3        4   Michael Mathews   30   Other                         Togo
# 4        5  Nicholas Sanchez   30  Female                      Morocco
# ...    ...               ...  ...     ...                          ...
# 2995  2996     Mary Bartlett   30   Other                    Macedonia
# 2996  2997      Beth Sanchez   30    Male                 Saudi Arabia
# 2997  2998       Megan Duffy   30    Male  Falkland Islands (Malvinas)
# 2998  2999    Jeffery Lawson   30    Male                      Bermuda
# 2999  3000      Kathryn Gray   30   Other                      Jamaica
#
#                city education_level employment_status  annual_income_usd  \
# ...

# %%
gone_case.iloc[0:10:, 3:4:] = 'Female'

# %%
gone_case
# Out:
#         id              name  age  gender                      country  \
# 0        1     Michael Bates   30  Female                        Yemen
# 1        2    Brian Thompson   30  Female                 Saudi Arabia
# 2        3     Steven Little   30  Female                         Togo
# 3        4   Michael Mathews   30  Female                         Togo
# 4        5  Nicholas Sanchez   30  Female                      Morocco
# ...    ...               ...  ...     ...                          ...
# 2995  2996     Mary Bartlett   30   Other                    Macedonia
# 2996  2997      Beth Sanchez   30    Male                 Saudi Arabia
# 2997  2998       Megan Duffy   30    Male  Falkland Islands (Malvinas)
# 2998  2999    Jeffery Lawson   30    Male                      Bermuda
# 2999  3000      Kathryn Gray   30   Other                      Jamaica
#
#                city education_level employment_status  annual_income_usd  \
# ...

# %%
# covid.set_index('Country/Region', inplace=True)
covid.loc['China':'China':, 'Confirmed'] = 100000000
covid.set_index('Country/Region', inplace= True)
covid.head(1)
# Out:
#                 Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# Country/Region
# Afghanistan         36263    1269      25198    9796        106          10
#
#                 New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Country/Region
# Afghanistan                18                 3.5                  69.49
#
#                 Deaths / 100 Recovered  Confirmed last week  1 week change  \
# Country/Region
# Afghanistan                       5.04                35526            737
#
#                 1 week % increase             WHO Region
# Country/Region
# Afghanistan                  2.07  Eastern Mediterranean

# %%
covid.iloc[0, 0]
covid.loc['China','Confirmed'] = 100000000

# %%
covid.loc['China', 'Confirmed']
# Out:
# np.int64(100000000)

# %%
covid.loc['China'][ 'Confirmed'] = 100
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6708\1855017007.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   covid.loc['China'][ 'Confirmed'] = 100

# %%
d = {'id': 'sr_no'}
gone_case.rename(columns=d, inplace=True)

# %%
gone_case.head(1)
# Out:
#    sr_no           name  age gender country         city education_level  \
# 0      1  Michael Bates   66  Other   Yemen  Martinmouth       Secondary
#
#   employment_status  annual_income_usd marital_status  ...  \
# 0           Student              45595        Married  ...
#
#    attempts_to_quit_smoking  attempts_to_quit_drinking  has_health_issues  \
# 0                         6                          2               True
#
#    mental_health_status  exercise_frequency  diet_quality  sleep_hours   bmi  \
# 0                  Good               Daily       Average          5.6  22.4
#
#   social_support therapy_history
# 0            NaN         Current
#
# [1 rows x 25 columns]

# %%
d = {'Male':'m', 'Female':'f', 'Other':'o'}
gone_case['gender'] = gone_case['gender'].map(d)

# %%
gone_case['gender']
# Out:
# 0       o
# 1       m
# 2       m
# 3       o
# 4       f
#        ..
# 2995    o
# 2996    m
# 2997    m
# 2998    m
# 2999    o
# Name: gender, Length: 3000, dtype: str

# %%
d = {'Male':'m', 'Female':'f', 'Other':np.nan}
gone_case['gender'] = gone_case['gender'].map(d)

# %%
gone_case.isnull().sum()
# Out:
# id                              0
# name                            0
# age                             0
# gender                       1024
# country                         0
# city                            0
# education_level               420
# employment_status               0
# annual_income_usd               0
# marital_status                  0
# children_count                  0
# smokes_per_day                  0
# drinks_per_week                 0
# age_started_smoking             0
# age_started_drinking            0
# attempts_to_quit_smoking        0
# attempts_to_quit_drinking       0
# has_health_issues               0
# mental_health_status            0
# exercise_frequency              0
# diet_quality                    0
# sleep_hours                     0
# bmi                             0
# social_support                753
# therapy_history              1014
# dtype: int64

# %%
gone_case['gender'] = gone_case['gender'].fillna(0)

# %%
gone_case['gender']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: gender, Length: 3000, dtype: bool

# %%
gone_case.drop(['id'], axis= 1, inplace = True)

# %%
gone_case.head(1)
# Out:
#             name  age gender country         city education_level  \
# 0  Michael Bates   66      0   Yemen  Martinmouth       Secondary
#
#   employment_status  annual_income_usd marital_status  children_count  ...  \
# 0           Student              45595        Married               3  ...
#
#    attempts_to_quit_smoking  attempts_to_quit_drinking  has_health_issues  \
# 0                         6                          2               True
#
#    mental_health_status  exercise_frequency  diet_quality  sleep_hours   bmi  \
# 0                  Good               Daily       Average          5.6  22.4
#
#   social_support therapy_history
# 0            NaN         Current
#
# [1 rows x 24 columns]
