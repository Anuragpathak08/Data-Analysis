# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Indexing on Pandas Series
# `sytnax : variable[index value]`

# %%
s = pd.Series([1,23,451,23,456])
s[0] # np.int64(1)
s[1] # np.int64(23)
s[2] # np.int64(451)
s[2] = 10 # items Assignment is also possible 
s
# s[9] # keyerror because index element not exist
# Out:
# 0      1
# 1     23
# 2     10
# 3     23
# 4    456
# dtype: int64

# %%
# s[-1] #keyerror because index element dosent exist

# %%
marks = {'physics': 83,
         'chemistry': 89,
         'maths': 84,
         'bio': 80,
         'English': 70,
         'Hindi': 70}

s2 = pd.Series(marks)
s2
# Out:
# physics      83
# chemistry    89
# maths        84
# bio          80
# English      70
# Hindi        70
# dtype: int64

# %%
# s2[0] # Error because we can only perform indexing with the label
s2['physics']
# Out:
# np.int64(83)

# %% [markdown]
# ## Slicing on Pandas Series<hr>
# `syntax : variable[start: end: step]`

# %%
s1 = pd.Series(np.arange(1, 20, 1))
s1[0:10:1]
s1[0:20:2]
s1[10::-1]
s1[ :10:-1]
s1[1:-10:2]
# Out:
# 1    2
# 3    4
# 5    6
# 7    8
# dtype: int64

# %%
s2['physics': 'Hindi': 1]
s2[0::1]
# Out:
# physics      83
# chemistry    89
# maths        84
# bio          80
# English      70
# Hindi        70
# dtype: int64

# %%
s3 = pd.Series(np.arange(7), index = [0,10,20,30,40,50,60])
s3
# Out:
# 0     0
# 10    1
# 20    2
# 30    3
# 40    4
# 50    5
# 60    6
# dtype: int64

# %%
s3[0:7:1]
s3[0:10:1]
# Out:
# 0     0
# 10    1
# 20    2
# 30    3
# 40    4
# 50    5
# 60    6
# dtype: int64

# %% [markdown]
# ## Boolean Filtering on Pandas Series

# %% [markdown]
# ## Attribute of Pandas Series

# %% [markdown]
# ### size

# %% [markdown]
# ### dtype

# %% [markdown]
# ### is_unique

# %% [markdown]
# ### name

# %% [markdown]
# ### index

# %% [markdown]
# ### values

# %% [markdown]
# ## Methods of Pandas

# %% [markdown]
# ### head

# %% [markdown]
# ### tail

# %% [markdown]
# ### sample

# %% [markdown]
# ### value_count
