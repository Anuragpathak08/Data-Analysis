# %%
# !pip install numpy

# %%
import numpy as np

# %%
arr1 = np.array(10) #0D array

# %%
arr2 = np.array([10,20,30,40,50,60]) #1D array

# %%
arr3 = np.array([[1,2,3],
                 [3,42,45],
                 [34,67,67]]) #2D array
