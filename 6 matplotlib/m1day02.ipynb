# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot([1, 12, 13, 34, 54])
plt.plot([2, 34, 56, 10, 34])

# %% [markdown]
# ### Subplot

# %%
plt.subplot(2,3,1)
plt.plot([1,2,34,56,7], [1,3,5,12, 15])


plt.subplot(2,3,2)
plt.plot([1,2,34,56,7], [12,34,345, 455, 456 ])

plt.subplot(2,3,4)
plt.plot([1,2,34,56,7], [12,34,345, 455, 456 ])

plt.subplot(2,3,6)
plt.plot([1,2,34,56,7], [12,34,345, 455, 456 ])

# %% [markdown]
# ### pie chart

# %%
countrys_gdp = [3.48, 2.66, 4.15, 0.0,]

plt.pie(countrys_gdp, 
        labels= ['usa', 'russia', 'India', 'pakistan'],
        # colors=['red', 'blue', 'white', 'brown'],
        autopct='%0.2f%%',
        # startangle=90,
        # startangle=180,
        # shadow=True
        explode=(0.4, 0.5, 0.3, 0.1)
        )
